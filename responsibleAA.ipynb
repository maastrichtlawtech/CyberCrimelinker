# %% [markdown]
# # **Loading libraries**

# %%
# Mount the drive if not mounted
from google.colab import drive
drive.mount("/content/drive/")

from IPython.display import Image
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
Image("/content/drive/MyDrive/AA-Tutorial/data/Images/AAresponsible.png", width=1000, height=700)

# %% [markdown]
# # **Privacy & Data Protection**
#
# - Does the AA research/application involve a high level of risk, necessitating a Data Protection Impact Assessment (DPIA)? High-risk scenarios may include biometric identification, law enforcement, or justice system usage.
# - Does the AA processing encompass extensive automated processing leading to decisions with legal or significant effects on individuals? Are measures in place to prevent identity disclosure, reputational damage, or legal consequences?
# - Is there a scientific purpose or objective justifying exemptions from GDPR provisions?
# - Is data processing confined to the original purpose for which it was collected? Is there periodic assessment and review to ensure ongoing relevance?
# - Does the dataset contain information enabling the identification of individuals?
# - Have adequate safeguards like anonymization, encryption, data minimization, and security procedures been implemented to minimize risks and protect individual rights? Are these measures in line with guidelines from research and academic organizations, with ethical oversight?
# - Is the information provided to individuals about data processing clear, complete, and correct?

# %% [markdown]
# # **Discrimination & Unintended Biases**
#
# - Is there a specific label or target for each data instance, and how were these labels obtained? For manually annotated data, please provide details about the number of annotators, their backgrounds, and any measures taken to mitigate label bias.
# - Does the training dataset sufficiently represent the entire authorship landscape, and what steps were taken to mitigate selection bias?
# - Are there correlations between authors in the dataset and specific demographic attributes or population characteristics?
# - Does the dataset cover multiple text genres or domains, and if not, what actions were taken to prevent biases related to domain and genre?
# - Is there a class imbalance in the dataset, and what measures were implemented to avoid overrepresenting certain authors? Describe any sampling strategies used to address potential sampling bias.
# - What feature extraction techniques were employed during training, and was fine-tuning performed on the target data?
# - What precautions were taken to prevent overfitting and underfitting during model training?
# - Do the chosen evaluation metrics align with the primary task objectives, and what insights can be provided about model generalization and robustness?
# - Were independent blind assessments conducted by external evaluators, and can information about their backgrounds and diversity be provided?

# %% [markdown]
# # **Transparency & Fairness**
#
# - Are any experiments conducted to gain insights into the model’s decision-making processes?
# - Are any error-analysis experiments conducted to understand false-positive and true-positive predictions?
# - Are any explainability/Interpretability experiments conducted to understand model learning and model predictions?

# %% [markdown]
# # **Societal Impact**
#
# - Is there a disclaimer to alert readers to potentially harmful content in the research?
# - Does the AA processing encompass systematic and extensive automated processing that leads to decisions with legal or significant effects on individuals? Are measures in place to prevent identity disclosure, reputational damage, or legal ramifications?
# - Does the scope of the AA model align with its intended purpose to minimize potential misuse?
# - Is there a mechanism to mitigate the risk of potential misuse and abuse, including scenarios involving targeted harassment, social engineering, or the creation of deceptive content falsely attributed to others?
# - Are there mechanisms for human oversight and intervention to review and reject content with ethical concerns?
# - What measures are in place to minimize the potential trauma experienced by individuals during the design, development, and deployment stages? Are there regular check-ins among team members to ensure clear communication and provide essential support for maintaining a healthy and safe working environment? Is mental health and psychological support offered to team members dealing with harmful text?
# - Is there a routine schedule of audits and updates to the AA model to anticipate and address potential ethical challenges? Do these audits and updates help ensure the model remains aligned with evolving ethical standards and societal expectations?
# - Are efficient algorithms and training strategies given priority to minimize the carbon footprint and energy consumption? Is carbon tracking employed to monitor and quantify carbon emissions during AA model training, aiding in optimization and offsetting strategies?
